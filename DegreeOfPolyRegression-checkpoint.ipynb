# %%
import numpy as np
import pandas as pd

df = pd.read_csv("C:/Users/Shraddha Nandagave/Downloads/UNZIP_FOR_NOTEBOOKS_V5/v5/08-Linear-Regression-Models/Advertising.csv")
# Read csv File

X = df.drop('sales',1)
y=df['sales']

# %%
#STEPS
#crete different order polynomial
#Split feature as train/test
#fit on train
#RMSE for train and test
#PLOT the result (Error Vs poly order)

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression 
#from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
train_rmse_errors=[]
test_rmse_errors=[]

for d in range(1,10):
    poly_converter = PolynomialFeatures(degree=d, include_bias=0)
    poly_feature= poly_converter.fit_transform(X)
    
    #from sklearn.model_selection import train_test_split
    X_train, X_test, y_train, y_test = train_test_split(poly_feature, y, test_size=0.3
                                                        , random_state=62)
    
    #from sklearn.linear_model import LinearRegression 
    model= LinearRegression()
    model.fit(X_train,y_train)
    
    train_pred = model.predict(X_train)
    test_pred = model.predict(X_test)
    
    train_mse= mean_squared_error(y_train,train_pred)
    test_mse = mean_squared_error(y_test, test_pred)
    
    train_rmse =np.sqrt(train_mse)
    test_rmse = np.sqrt(test_mse)
    
    train_rmse_errors.append(train_rmse)
    test_rmse_errors.append(test_rmse)

# %%
train_rmse_errors
# Out:
# [1.5255222626590248,
#  0.45161515705165317,
#  0.3333405769528335,
#  0.27912242049968167,
#  0.23132854256956562,
#  0.1892469052424351,
#  0.23479037427489272,
#  0.16646357702909848,
#  0.22852399860357678]

# %%
test_rmse_errors
# Out:
# [1.9768250830660175,
#  0.9070386115165187,
#  0.7763192895780149,
#  0.8353471522476428,
#  0.5045416057126201,
#  0.9985807128487779,
#  26.289141891039392,
#  473.1746923894027,
#  3640.5959451550475]

# %% [raw]
# Plott
# ing train_rmse_errors and test_rmse_errors to choose optimum degree of polynomial

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(range(1,6),train_rmse_errors[:5], label='TRAIN_RMSE')
plt.plot(range(1,6),test_rmse_errors[:5], label='TEST_RMSE')

plt.ylabel('RMSE')
plt.xlabel('degree of polynomial')
plt.legend()

# %%
plt.plot(train_rmse_errors, label='TRAIN_RMSE')
plt.plot(test_rmse_errors, label='TEST_RMSE')

plt.ylabel('RMSE')
plt.xlabel('degree of polynomial')
plt.legend()

# %% [raw]
# from graphs,
# degree = 3

# %%
final_poly_converter = PolynomialFeatures(degree=3,include_bias= 0)

# %%
final_model= LinearRegression()

# %%
final_converted_X = final_poly_converter.fit_transform(X)

# %%
final_model.fit(final_converted_X,y)
# Out:
# LinearRegression()

# %% [markdown]
# Joblib is a set of tools to provide lightweight pipelining in Python.
# In particular:
# 1. transparent disk-caching of functions and lazy re-evaluation (memoize pattern)
# 2. easy simple parallel computing

# %%
from joblib import dump,load

# %% [raw]
# dumping finalmodel

# %%
dump(final_model,'final_model.joblib' )
# Out:
# ['final_model.joblib']

# %%
dump(final_poly_converter,'final_poly_converter.joblib')
# Out:
# ['final_poly_converter.joblib']

# %%
loaded_converter = load('final_poly_converter.joblib')

# %%
loaded_model = load('final_model.joblib')

# %% [markdown]
# Predicting for new value

# %%
campaign= [[149,22,12],[678,98,25]]

# %%
transformed_data= loaded_converter.fit_transform(campaign)

# %%
loaded_model.predict(transformed_data)
# Out:
# array([ 14.64501014, 153.77330806])
